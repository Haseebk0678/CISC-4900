# %%
import numpy as np
from tensorflow.keras.models import load_model
import cv2
import numpy as np
from PIL import Image
from keras import models
import pandas as pd
import os

# %%
model = load_model('best_model_4.h5')
input_shape = (100,100)
# Out:
# 2023-05-05 09:47:08.794002: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# import cv2
# import tkinter as tk
# from PIL import Image, ImageTk

# class CameraApp:
#     def __init__(self, master):
#         self.master = master
#         master.title("Camera App")

#         # Create a button to take a picture
#         self.button = tk.Button(master, text="Take Picture", command=self.take_picture)
#         self.button.pack()

#         # Create a canvas to display the captured image
#         self.canvas = tk.Canvas(master, width=640, height=480)
#         self.canvas.pack()

#     def take_picture(self):
#         # Open the default camera
#         cap = cv2.VideoCapture(0)

#         # Capture a frame from the camera
#         ret, frame = cap.read()

#         # Save the captured frame as an image
#         self.image = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))

#         # Release the camera
#         cap.release()

#         # Display the captured image on the canvas
#         self.photo = ImageTk.PhotoImage(self.image)
#         self.canvas.create_image(0, 0, image=self.photo, anchor=tk.NW)

# root = tk.Tk()
# app = CameraApp(root)
# root.mainloop()

# %%
import cv2

cam = cv2.VideoCapture(0)

cv2.namedWindow("test")

img_counter = 0

while True:
    ret, frame = cam.read()
    if not ret:
        print("failed to grab frame")
        break
    cv2.imshow("test", frame)

    k = cv2.waitKey(1)
    if k%256 == 27:
        # ESC pressed
        print("Escape hit, closing...")
        break
    elif k%256 == 32:
        # SPACE pressed
        img_name = "opencv_frame_{}.png".format(img_counter)
        cv2.imwrite(img_name, frame)
        print("{} written!".format(img_name))
        img_counter += 1

cam.release()

cv2.destroyAllWindows()
# Out:
# opencv_frame_0.png written!
# opencv_frame_1.png written!
# opencv_frame_2.png written!
# opencv_frame_3.png written!
# opencv_frame_4.png written!
# opencv_frame_5.png written!
# opencv_frame_6.png written!
# opencv_frame_7.png written!
# opencv_frame_8.png written!
# opencv_frame_9.png written!
# opencv_frame_10.png written!
# opencv_frame_11.png written!
# opencv_frame_12.png written!
# opencv_frame_13.png written!
# Escape hit, closing...

# %%
# from flask import Flask

# app = Flask(__name__)

# @app.route("/")
# def hello_world():
#     return "<p>Hello, World!</p>"

# %%
import cv2

img = cv2.imread(os.path.join('opencv_frame_0.png'))
grayscale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
resized = cv2.resize(grayscale, input_shape)
resized = np.reshape(resized, input_shape[0] * input_shape[1])


# prediction = model.predict(image)
resized

# %%
# https://medium.com/@jinilcs/a-simple-keras-model-on-my-laptop-webcam-dda77521e6a0
import cv2
import numpy as np
from PIL import Image
from keras import models
import pandas as pd

#Load the saved model
video = cv2.VideoCapture(0)
input_shape = (100,100)

while True:
    _, frame = video.read()

    # frame = cv2.imread(filename)
    #Convert the captured frame into RGB
    im = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    faces = face_cascade.detectMultiScale(frame, 1.1, 4)

    # Draw rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

        
    # Display the output
    face_im = im[y:y+h, x:x+w]
    resized = cv2.resize(face_im, input_shape)
    resized = np.reshape(resized, input_shape[0] * input_shape[1])
    im_df = pd.DataFrame(resized)
    #Resizing into 100x100 because we trained the model with this image size.
    X = im_df / 255.0
    X = X.values.reshape(-1,100,100,1)
    #Calling the predict method on model to predict 'me' on the image
    print(model.predict(X)[0][0])
    prediction = model.predict(X)[0][0]
    print(prediction)
#    Closer prediction is to 1, stronger guess of NO MASK, closer is to 1, stronger guess of mask
    if prediction < .6:
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        label = "No Mask"
        cv2.putText(frame, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    else:
        label = "Mask"
        cv2.putText(frame, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    cv2.imshow("Capturing", frame)
    key=cv2.waitKey(1)
    if key == ord('q'):
            break
# video.release()
# cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 215ms/step
# 0.9247649
# 1/1 [==============================] - 0s 60ms/step
# 0.9247649
# 1/1 [==============================] - 0s 97ms/step
# 0.86731356
# 1/1 [==============================] - 0s 102ms/step
# 0.86731356
# 1/1 [==============================] - 0s 91ms/step
# 0.49608657
# 1/1 [==============================] - 0s 139ms/step
# 0.49608657
# 1/1 [==============================] - 0s 47ms/step
# 0.58475405
# 1/1 [==============================] - 0s 140ms/step
# 0.58475405
# 1/1 [==============================] - 0s 149ms/step
# 0.7332694
# 1/1 [==============================] - 0s 95ms/step
# 0.7332694
# 1/1 [==============================] - 0s 52ms/step
# 0.86308724
# 1/1 [==============================] - 0s 177ms/step
# 0.86308724
# 1/1 [==============================] - 0s 66ms/step
# 0.48467723
# 1/1 [==============================] - 0s 66ms/step
# 0.48467723
# 1/1 [==============================] - 0s 64ms/step
# ...

# %%
# Load the saved model
# Define a function to make predictions
input_shape = (100,100)
def predict_mask(image):

    frame = cv2.imread(image)
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    faces = face_cascade.detectMultiScale(frame, 1.1, 4)

    # Draw rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

    # Display the output
    cv2.imshow('img', frame)
    cv2.waitKey()
    
    
    print(frame.shape)
    image = cv2.resize(frame, input_shape)
    image_array = np.array(image)
    image_array = np.resize(image_array, (1, 100, 100))
    
    image_array = image_array / 255.0
    print(image_array.shape)
    
    # Make a prediction with the model
    prediction = model.predict(image_array)
    print(prediction)
    
    # Return the prediction
    return prediction[0][0] > 0.5  # Returns True if wearing mask, False if not

# Example usage
# image = 'New_Masks_Dataset/Test/Mask/2085.jpg'
# image = 'New_Masks_Dataset/Test/Non_Mask/real_01032.jpg'
# image = 'New_Masks_Dataset/Test/Mask/2114.jpeg'
# image = 'New_Masks_Dataset/Test/Non_Mask/real_01042.jpg'
# image = 'mask.png'
# image = 'no_mask.png'
# image = 'opencv_frame_0.png'
# image = 'opencv_frame_1.png'

# image = "New_Masks_Dataset/Test/Non_Mask/real_01073.jpg"
# folder = 'New_Masks_Dataset/Test/Non_Mask'
# for image in os.listdir(folder):
prediction = predict_mask(image)
print(prediction)
# Out:
# (646, 970)
# (1, 100, 100)
# 1/1 [==============================] - 0s 37ms/step
# [[2.605992e-11 1.000000e+00]]
# False

# %% [markdown]
# For the first model adding in the rotations and changes to the data set made the prediction DID NOT HAVE AN EFFECT on the accuracy of the data, I am going to be increasing the amount of transformations and see the effect it has

# %%
model = load_model('best_model_3.h5')
# Change to input_shape = (100,100,3) if using _2 2,3,5
input_shape = (100,100)

# %%
# Load the saved model
# Define a function to make predictions
input_shape = (100,100)

def predict_mask(image):

    frame = cv2.imread(image)
#     frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(frame, input_shape)
    # Convert the image to a numpy array
    image_array = np.array(image)
    
    # Resize the image to the correct dimensions (if necessary)
    image_array = np.resize(image_array, (1, 100, 100,3))
    
    # Normalize the image data
    image_array = image_array / 255.0
    print(image_array.shape)
    
    # Make a prediction with the model
    prediction = model.predict(image_array)
    print(prediction)
    
    # Return the prediction
    return prediction[0][0] > 0.5  # Returns True if wearing mask, False if not

# Example usage
# image = 'New_Masks_Dataset/Test/Mask/2085.jpg'
# image = 'New_Masks_Dataset/Test/Non_Mask/real_01032.jpg'
# image = 'New_Masks_Dataset/Test/Mask/2114.jpeg'
# image = 'New_Masks_Dataset/Test/Non_Mask/real_01042.jpg'
image = 'mask.png' 
# image = 'no_mask.png'
# image = "New_Masks_Dataset/Test/Non_Mask/real_01073.jpg"
# folder = 'New_Masks_Dataset/Test/Non_Mask'
# for image in os.listdir(folder):
prediction = predict_mask(image)
print(prediction)
# Out:
# (1, 100, 100, 3)
# 1/1 [==============================] - 0s 271ms/step
# [[0.9571363  0.04233744]]
# True

# %%
import numpy as np
from tensorflow.keras.models import load_model
import cv2
import numpy as np
from PIL import Image
from keras import models
import pandas as pd
import os

# %%
model = load_model('best_model_3.h5')
# Change to input_shape = (100,100,3) if using _2 2,3,5
input_shape = (100,100)
# Out:
# 2023-05-05 11:46:34.164646: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# https://medium.com/@jinilcs/a-simple-keras-model-on-my-laptop-webcam-dda77521e6a0
import cv2
import numpy as np
from PIL import Image
from keras import models
import pandas as pd

#Load the saved model
video = cv2.VideoCapture(0)
input_shape = (100,100)
video.set(10,100)

while True:
    _, frame = video.read()

    # frame = cv2.imread(filename)
    #Convert the captured frame into RGB
    im = frame
    
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    faces = face_cascade.detectMultiScale(frame, 1.1, 4)
#     print(faces)
    # Draw rectangle around the faces
    face_im = im
    for (x, y, w, h) in faces:
        face_im = im[y:y+h, x:x+w]
    
    resized = cv2.resize(face_im, input_shape)
    # Convert the image to a numpy array
    image_array = np.array(resized)
    
    # Resize the image to the correct dimensions (if necessary)
    image_array = np.resize(image_array, (1, 100, 100,3))
    
    # Normalize the image data
    image_array = image_array / 255.0
    # Make a prediction with the model
    prediction = model.predict(image_array)
    print(prediction)
#    Closer prediction is to 1, stronger guess of NO MASK, closer is to 1, stronger guess of mask
    pred = prediction[0][0] * 100

    if prediction[0][0] > .6:
        label = "No Mask"
        pred = prediction[0][0]*100
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 255), 2)
            cv2.putText(frame, label + " " +str(pred), (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
    else:
        label = "Mask"
        pred = prediction[0][1]*100
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
            cv2.putText(frame, label +" "+ str(pred), (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    cv2.imshow("Capturing", frame)
    key=cv2.waitKey(1)
    if key == ord('q'):
            break
# video.release()
# cv2.destroyAllWindows()
# Out:
# [[471  91 352 352]]
# 1/1 [==============================] - 1s 766ms/step
# [[0.7274765  0.28395122]]
# [[468 103 352 352]]
# 1/1 [==============================] - 0s 61ms/step
# [[0.7992945  0.21352924]]
# [[465 100 352 352]
#  [574 617  40  40]]
# 1/1 [==============================] - 0s 34ms/step
# [[0.26806003 0.73345554]]
# [[514 208 333 333]]
# 1/1 [==============================] - 0s 45ms/step
# [[0.7744429  0.24076083]]
# [[497 188 321 321]]
# 1/1 [==============================] - 0s 209ms/step
# [[0.823274   0.19005653]]
# [[434 117 417 417]]
# 1/1 [==============================] - 0s 65ms/step
# [[0.86225325 0.14768705]]
# [[489 318 364 364]]
# 1/1 [==============================] - 0s 38ms/step
# [[0.8590151  0.15385072]]
# [[475 265 419 419]]
# 1/1 [==============================] - 0s 31ms/step
# [[0.8411103  0.16898379]]
# [[487 273 440 440]]
# 1/1 [==============================] - 0s 37ms/step
# [[0.89135814 0.11808728]]
# [[500 197 501 501]]
# ...

# %% [markdown]
# For the 2nd model which contained COLOR AND the rotations/changes to the data set. It made the accuracy in guessing between the two options A LOT WORSE

# %% [markdown]
# For the 3nd model which contained COLOR AND the rotations/changes, AND did not have a class_mode set to it, it made the false positve rate a lot higher, what this means is that most of the images are returning as true and even some of the stock photos which shouldn't have a high score are having a high score

# %% [markdown]
# For the 4nd model which contained did NOT contain COLOR AND but did have some transformations and the main thing about this is that it made in this one I worked to destory the training images, that ufortantely did not have as big of an effect as I would've liked to have and while it did make the values the test a lot higher it made the values for other images to be a lot worse.
